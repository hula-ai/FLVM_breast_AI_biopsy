# %%
import os
import glob

# %%
embed_root = '/home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original/EMBED_images_pngs/findings'

# %%
all_img_tfds_dir = glob.glob(os.path.join(embed_root, '*images*tfds*'))

# %%
for img_dir in all_img_tfds_dir:
    print(img_dir)

    print(len(glob.glob(os.path.join(img_dir, 'train', '**', '*.png'), recursive=True)))
    print(len(glob.glob(os.path.join(img_dir, 'test', '**', '*.png'), recursive=True)))
# Out:
# /home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original/EMBED_images_pngs/findings/images_tfds
# 105500
# 35620
# /home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original/EMBED_images_pngs/findings/images_unique_mapping_tfds
# 5910
# 1980
# /home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original/EMBED_images_pngs/findings/images_unique_mapping_tfds_fold_0
# 6330
# 1560
# /home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original/EMBED_images_pngs/findings/images_unique_mapping_tfds_fold_1
# 6430
# 1460
# /home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original/EMBED_images_pngs/findings/images_unique_mapping_tfds_fold_2
# 6430
# 1460
# /home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original/EMBED_images_pngs/findings/images_unique_mapping_tfds_fold_3
# 6200
# 1710
# /home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original/EMBED_images_pngs/findings/images_unique_mapping_tfds_fold_4
# ...

# %%
from MultiMEDal_multimodal_medical.src.datasets.EMBED import (
    EMBED_dataset,
    EMBED_whole_mamm_dataset,
    EMBED_dataset_tfds,
    EMBED_tabular_dataset
)

transform_dict = {'train': None, 'val': None, 'test': None}

train_dataset = EMBED_dataset_tfds(
    data_root="/home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original",
    dataset_dir="images_unique_mapping_tfds",
    incl_bg=False,
    split="train",
    class_type="2classes",
    incl_tabular=True,
    transform=transform_dict["train"],
)
val_dataset = EMBED_dataset_tfds(
    data_root="/home/hqvo2/Projects/MultiMEDal_multimodal_medical/data/EMBED/original",
    dataset_dir="images_unique_mapping_tfds",
    incl_bg=False,
    split="test",
    class_type="2classes",
    incl_tabular=True,
    transform=transform_dict["val"],
)
# Out:
# /home/hqvo2/Projects/MultiMEDal_multimodal_medical/src/datasets/EMBED.py:1198: DtypeWarning: Columns (28,31,33,48,49,53,54,55,56,57,59,81,84,85,93,111) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_clinical = pd.read_csv(os.path.join(self.data_root, "tables/EMBED_OpenData_clinical.csv"))
# /home/hqvo2/Projects/MultiMEDal_multimodal_medical/src/datasets/EMBED.py:1206: DtypeWarning: Columns (115,116,117,118,119,120,130,132,133,134,135,136,138,143,147,148,149) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_metadata = pd.read_csv(os.path.join(self.data_root, "tables/EMBED_OpenData_metadata.csv"))
# ...

# %%
len(train_dataset)
# Out:
# 5610
